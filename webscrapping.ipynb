# %% [markdown]
# <a href="https://colab.research.google.com/github/dpksomvanshi/web_scrapping/blob/main/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
  URL = 'https://en.wikipedia.org/wiki/List_of_national_capitals_by_population'

# %%
tables = pd.read_html(URL)

# %%
len(tables)
# Out:
# 4

# %%
tables[0]
# Out:
#                                    Lists of capitals
#                                         Of countries
# 0  in alphabetical order By latitude By populatio...
# 1                            Of country subdivisions
# 2  Capitals outside the territories they serve Pu...
# 3                                      Cities portal
# 4  .mw-parser-output .navbar{display:inline;font-...

# %%
tables[1]
# Out:
#                                 Country (or territory)            Capital  \
# 0                                              China *            Beijing
# 1                                              Japan *              Tokyo
# 2                                           DR Congo *           Kinshasa
# 3                                             Russia *             Moscow
# 4                                          Indonesia *            Jakarta
# ..                                                 ...                ...
# 235                         Norfolk Island (Australia)           Kingston
# 236                                              Palau          Ngerulmud
# 237                Cocos (Keeling) Islands (Australia)        West Island
# 238                              Pitcairn Islands (UK)          Adamstown
# 239  South Georgia and the South Sandwich Islands (UK)  King Edward Point
#
#     Population % of country    Source
# 0     21542000          NaN  [1] 2018
# ...

# %%
df = tables[2]

# %%
df.head()
# Out:
#   vteWorld's largest cities                        vteWorld's largest cities.1
# 0               City proper  Capitals Africa Americas (North Latin Central ...
# 1         Metropolitan area  Americas (North South West Indies) Europe (Eur...
# 2  Urban area/agglomeration  Asia Africa Europe European Union Nordic North...
# 3                Historical                                       World Europe
# 4          Related articles  Arcology Ecumenopolis Global city Megacity Meg...

# %%
df1 = tables[1]

# %%
df1.head()
# Out:
#   Country (or territory)   Capital Population % of country    Source
# 0                China *   Beijing   21542000          NaN  [1] 2018
# 1                Japan *     Tokyo   13921000          NaN  [2] 2019
# 2             DR Congo *  Kinshasa   12691000          NaN  [3] 2017
# 3               Russia *    Moscow   12655050          NaN  [4] 2021
# 4            Indonesia *   Jakarta   10562088          NaN  [5] 2020

# %%
df1.to_csv('Country.csv')
